# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./archive/Train_data.csv")

# %%
df.head()
# Out:
#    duration protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0          icmp       20     2        491          0     0
# 1         0           udp       45     2        146          0     0
# 2         0          icmp       50     4          0          0     0
# 3         0          icmp       25     2        232       8153     0
# 4         0          icmp       25     2        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
df.describe()
# Out:
#            duration        service           flag     src_bytes     dst_bytes  \
# count  125973.00000  125973.000000  125973.000000  1.259730e+05  1.259730e+05
# mean      287.14465      32.086288       2.575179  4.556674e+04  1.977911e+04
# std      2604.51531      16.462574       1.141552  5.870331e+06  4.021269e+06
# min         0.00000       1.000000       1.000000  0.000000e+00  0.000000e+00
# 25%         0.00000      20.000000       2.000000  0.000000e+00  0.000000e+00
# 50%         0.00000      25.000000       2.000000  4.400000e+01  0.000000e+00
# 75%         0.00000      50.000000       4.000000  2.760000e+02  5.160000e+02
# max     42908.00000      70.000000      11.000000  1.379964e+09  1.309937e+09
#
#                 land  wrong_fragment         urgent            hot  \
# count  125973.000000   125973.000000  125973.000000  125973.000000
# mean        0.000198        0.022687       0.000111       0.204409
# ...

# %%
df.isna().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
df.size
# Out:
# 5290866

# %%
df1 = df.drop(["duration"] , axis=1)

# %%
df1.head()
# Out:
#   protocol_type  service  flag  src_bytes  dst_bytes  land  wrong_fragment  \
# 0          icmp       20     2        491          0     0               0
# 1           udp       45     2        146          0     0               0
# 2          icmp       50     4          0          0     0               0
# 3          icmp       25     2        232       8153     0               0
# 4          icmp       25     2        199        420     0               0
#
#    urgent  hot  num_failed_logins  ...  dst_host_srv_count  \
# 0       0    0                  0  ...                  25
# 1       0    0                  0  ...                   1
# 2       0    0                  0  ...                  26
# 3       0    0                  0  ...                 255
# 4       0    0                  0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# ...

# %%
df1["protocol_type"].unique()
# Out:
# array(['icmp', 'udp', 'tcp'], dtype=object)

# %%
dummies = pd.get_dummies(df1.protocol_type)
dummies
# Out:
#         icmp  tcp  udp
# 0          1    0    0
# 1          0    0    1
# 2          1    0    0
# 3          1    0    0
# 4          1    0    0
# ...      ...  ...  ...
# 125968     1    0    0
# 125969     0    0    1
# 125970     1    0    0
# 125971     1    0    0
# 125972     1    0    0
#
# [125973 rows x 3 columns]

# %%
df1.xAttack.unique()
# Out:
# array(['normal', 'dos', 'r2l', 'probe', 'u2r'], dtype=object)

# %%
dumy_y = pd.get_dummies(df1.xAttack)

# %%
df2 = df1.drop(["xAttack"],axis =1)

# %%
df2.columns
# Out:
# Index(['protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
#        'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in',
#        'num_compromised', 'root_shell', 'su_attempted', 'num_root',
#        'num_file_creations', 'num_shells', 'num_access_files',
#        'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count',
#        'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate',
#        'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate',
#        'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count',
#        'dst_host_same_srv_rate', 'dst_host_diff_srv_rate',
#        'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate',
#        'dst_host_serror_rate', 'dst_host_srv_serror_rate',
#        'dst_host_rerror_rate', 'dst_host_srv_rerror_rate'],
#       dtype='object')

# %%
df3 = pd.concat([df2 , dummies],axis=1)

# %%
df3.head()
# Out:
#   protocol_type  service  flag  src_bytes  dst_bytes  land  wrong_fragment  \
# 0          icmp       20     2        491          0     0               0
# 1           udp       45     2        146          0     0               0
# 2          icmp       50     4          0          0     0               0
# 3          icmp       25     2        232       8153     0               0
# 4          icmp       25     2        199        420     0               0
#
#    urgent  hot  num_failed_logins  ...  dst_host_diff_srv_rate  \
# 0       0    0                  0  ...                    0.03
# 1       0    0                  0  ...                    0.60
# 2       0    0                  0  ...                    0.05
# 3       0    0                  0  ...                    0.00
# 4       0    0                  0  ...                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df4 = df3.drop(["protocol_type"],axis=1)
df6 = (df4 - df4.mean())/df4.std()
X_numpy = df6.values
X_numpy.shape
# Out:
# (125973, 42)

# %% [markdown]
# X -> df6  = sari wo values ho independent han <b>
# y wo han jo ka depnt karta han

# %%
y = dumy_y.values
y.shape
# Out:
# (125973, 5)

# %% [markdown]
# ### Build the model

# %% [markdown]
# Standarize the data

# %%
from keras import models
from keras import layers
from keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from keras import metrics
from sklearn.model_selection import train_test_split

# %%
model = models.Sequential()
model.add(layers.Dense(32 , activation='relu' , input_dim=X_numpy.shape[1] ))
model.add(layers.Dense(16 , activation='relu' ))
model.add(layers.Dense(8 , activation='relu' ))
model.add(layers.Dense(y.shape[1], activation='sigmoid'))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=[metrics.categorical_accuracy])
from tensorflow.keras.callbacks import EarlyStopping
monitors = EarlyStopping(min_delta=1e-3,patience=5 ,
                         verbose=1 ,restore_best_weights =True)
x_train,x_test , y_train , y_test =train_test_split(df4.values,y,random_state=1)

history=model.fit(x_train,y_train ,validation_data=(x_test,y_test),callbacks=[monitors],epochs=100)
# Out:
# Epoch 1/100
# 2953/2953 [==============================] - 9s 3ms/step - loss: 17.0880 - categorical_accuracy: 0.7509 - val_loss: 0.2860 - val_categorical_accuracy: 0.9325
# Epoch 2/100
# 2953/2953 [==============================] - 7s 3ms/step - loss: 0.2611 - categorical_accuracy: 0.9371 - val_loss: 0.2144 - val_categorical_accuracy: 0.9468
# Epoch 3/100
# 2953/2953 [==============================] - 6s 2ms/step - loss: 0.2063 - categorical_accuracy: 0.9499 - val_loss: 0.1918 - val_categorical_accuracy: 0.9535
# Epoch 4/100
# 2953/2953 [==============================] - 5s 2ms/step - loss: 0.1857 - categorical_accuracy: 0.9548 - val_loss: 0.1988 - val_categorical_accuracy: 0.9542
# Epoch 5/100
# 2953/2953 [==============================] - 4s 1ms/step - loss: 0.1874 - categorical_accuracy: 0.9561 - val_loss: 0.1892 - val_categorical_accuracy: 0.9561
# Epoch 6/100
# ...

# %%
history_dict = history.history
history_dict.keys()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## <b> Loss

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values)+ 1)
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## <b> Accuracy

# %%
plt.clf()
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.save("model_save")
